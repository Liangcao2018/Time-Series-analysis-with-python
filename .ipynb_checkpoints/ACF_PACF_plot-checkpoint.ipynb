# %%
import pandas as pd
from pandas.plotting import lag_plot
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import statsmodels.api as sm
from statsmodels.tsa.stattools import acovf, acf, pacf, pacf_yw, pacf_ols
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# %matplotlib inline

# %%
# Non Satitoanry
airline=pd.read_csv('../Data/airline_passengers.csv',index_col='Month', parse_dates=True)
airline.index.freq='MS'
airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
# Satitoanry 
dtfb=pd.read_csv('/opsmnt/Projects/TSA_COURSE_NOTEBOOKS/Data/DailyTotalFemaleBirths.csv',index_col='Date', parse_dates=True)
dtfb.index.freq='D'
dtfb.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
df = pd.DataFrame({'a':[13,5,11,12,9]})
df
# Out:
#     a
# 0  13
# 1   5
# 2  11
# 3  12
# 4   9

# %%
acf(df['a'])
# Out:
# array([ 1.   , -0.5  , -0.2  ,  0.275, -0.075])

# %%
#yw : yule walker
pacf_yw(df['a'],nlags=df.shape[0]-1,method='mle')
# Out:
# array([ 1.        , -0.5       , -0.6       , -0.38541667, -0.40563273])

# %%
pacf_ols(df['a'],nlags=df.shape[0]-1)
# Out:
# array([ 1.        , -0.49677419, -0.43181818,  0.53082621,  0.25434783])

# %%
lag_plot(airline['Thousands of Passengers']);

# %%
lag_plot(dtfb['Births']);

# %%
airline.plot(figsize=(10,6));

# %%
plot_acf(airline,lags=40);

# %%
plot_acf(dtfb,lags=40);

# %%
plot_pacf(dtfb,lags=40,title='Daily Female Births');

# %%
plot_pacf(airline,lags=40, title='Airline passenger traffic');
